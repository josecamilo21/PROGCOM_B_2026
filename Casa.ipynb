# %% [markdown]
# <a href="https://colab.research.google.com/github/josecamilo21/PROGCOM_B_2026/blob/main/Casa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
color_techo="ladrillo"
color_pared="blanco con rojo"
cant_ventanas=2
cant_puertas=2
cant_pisos=1
cant_baños=2
color_marco_ventanas="ocre"
decoración_flores=True
flores_decoración=[]
nombre_letrero="No le puse"

# %%
def decorado_floristeria(a,b,c,d,e,f,g,h,nombre_letrero):
  color_techo=a
  color_pared=b
  cant_ventanas=c
  cant_puertas=d
  cant_pisos=e
  cant_baños=f
  color_marco_ventanas=g
  decoración_flores=h
  flres_decoración=i
  letrero=j
  if j: nombre_letrero=input("Cual es el nobre de la floristeria")

# %%
def
