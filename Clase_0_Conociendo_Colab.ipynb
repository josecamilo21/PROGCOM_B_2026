# %% [markdown]
# ##Ejercicios Tanda 1

# %% [markdown]
# #Titulo de nivel 1
# ##Titulo de nivel 2
# ###Titulo de nivel 3
#
# Hola, como estas? 😊
# 1. Hola
# 2. Como
# 3. Estas
#
# * Yo
# * Muy
# * Bien
#
#
#
# ```
# if (condición)
# aquí va la condicion si se cumple
# else:
# aqui va si la condicon no se cumple
# ```

# %% [markdown]
# ##Input
# Input es una funcion, que permite ingresar datos.
#
# Posee tres funciones
# 1. Lee: Se puede ingresar informacion
# 2. Almacena: Guarda la informacion de una variable (var)
# 3. Declara: Todos los datos almacenados los vuelve string
#
# Sintaxis
#
#
#
# ```
# var=input(Aquí va su impresión)
# ```
# Si se desea realizar una lectura de un tipo de dato diferente a string, se debe realizar una conversión de datos.
# Para ello, coloque el tipo de dato que desea convertir. y encierre el tipo original de dato entre paréntesis.
#
#
#
# ```
# var=int(input()) #Aquí se va a tranformar un dato de string a entero
# var2=float(input()) #Se transforma de string a decimal
# var3=bool(input()) #Se transforma de string a booleano
# ```

# %% [markdown]
# ###Saludando al mundo

# %%
print("hola mundo 👌")
# Out:
# hola mundo 👌

# %%
nombre= input("Cómo te llamas?")
# Out:
# Cómo te llamas?Camilo

# %%
nombre
# Out:
# 'Camilo'

# %%
edad1=int(input(f"Cual es tu edad, {nombre}?"))
# Out:
# Cual es tu edad, Camilo?17

# %%
edad2=int(input("Cual es tu edad del compañero de al lado?"))
# Out:
# Cual es tu edad del compañero de al lado?16

# %%
print(f"La suma de las dos edades es {edad1+edad2}")
# Out:
# La suma de las dos edades es 33
